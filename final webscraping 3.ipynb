# %% [markdown]
# 1) Write a python program which searches all the product under a particular product vertical from www.amazon.in.
#
# The product verticals to be searched will be taken as input from user.
#
# For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#importing necessary libraries

import pandas as pd  #pandas are for making dataframes
import selenium      #for automating
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException #for exception handling

# %%
#automating the browser using webdriver

driver = webdriver.Chrome(r"C:\Users\91950\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.amazon.in/")

# %%
#searching for guitars on search page by using selenium

search = driver.find_element_by_id("twotabsearchtextbox")
search.send_keys("Guitar")

search_btn = driver.find_element_by_id("nav-search-submit-button")
search_btn.click()

# %% [markdown]
# 2) In the above question, now scrape the following details of each product listed in first 3 pages of your search results
#
# and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape
#
# all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product",
#
# "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product
#
# URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# We have to go to each page to extract the above information

urls = []
for i in driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']"):
    urls.append(i.get_attribute("href"))

len(urls)
# Out:
# 67

# %%
#applying loops
brand_name = [] product_name = [] rating_total = [] price = []
for i in urls:
    driver.get(i) 
    try:
        brand = driver.find_element_by_xpath("//td[@class='a-span9']/span")
        brand_name.append(brand.text)
    except:
        brand_name.append('-')         
    try:
        product =  driver.find_element_by_id("productTitle")
        product_name.append(product.text)
    except:
        product_name.append('-')   
    try:
        rate = driver.find_element_by_id("acrCustomerReviewText")
        rating_total.append(rate.text)
    except:
        rating_total.append('-')
    try:
        total_price = driver.find_element_by_id("priceblock_dealprice")
        price.append(total_price.text)
    except:
        price.append('-')       
        
len(brand_name)
len(product_name)
len(rating_total)
len(price)
# Out:
# 67

# %%
# making a dataframe

product_page = pd.DataFrame({})

product_page['Brand']= brand_name
product_page['Name of the product']= product_name
product_page['number of ratings']= rating_total
product_page['price of the item']= price
product_page['url of the page']= urls

product_page  #displaying the dataset
# Out:
#            Brand                                Name of the product  \
# 0       Honestum  Honestum 4-string acoustic guitar learning kid...
# 1         Juârez  Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...
# 2         Intern  Intern INT-38C Acoustic Guitar Kit, With Bag, ...
# 3         JUAREZ  Juarez Acoustic Guitar Kit, 38 Inch Cutaway, 3...
# 4        Kadence  Kadence Guitar Acoustica Series, Electric Acou...
# ..           ...                                                ...
# 62        Intern  Intern INT-38C Acoustic Guitar Kit, With Bag, ...
# 63     TECHBLAZE  TECHBLAZE Acoustic Guitar Strings, Guitar Wall...
# 64             -  SG Musical Acoustic Guitar Strings | guitar st...
# 65             -  HEALLILY Guitar Fretboard Stickers Guitar Fret...
# 66  HRB musicals  HRB MUSICALS combo of guitar String Winder, gu...
#
#    number of ratings price of the item  \
# 0          3 ratings                 -
# 1     13,326 ratings         ₹1,999.00
# 2      7,231 ratings         ₹1,790.00
# 3      4,486 ratings         ₹1,999.00
# 4        727 ratings         ₹6,174.00
# ..               ...               ...
# 62       495 ratings         ₹1,749.00
# 63          1 rating                 -
# 64                 -                 -
# 65                 -                 -
# 66         7 ratings                 -
#
#                                       url of the page
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# 2   https://www.amazon.in/Intern-INT-38C-Acoustic-...
# 3   https://www.amazon.in/JUAREZ-JRZ38C-Acoustic-S...
# 4   https://aax-eu.amazon.in/x/c/QpB_2B9ns4Txpv_GE...
# ..                                                ...
# 62  https://www.amazon.in/Intern-INT-38C-Acoustic-...
# 63  https://www.amazon.in/TECHBLAZE-Acoustic-Guita...
# 64  https://www.amazon.in/SG-Musical-Acoustic-Stri...
# 65  https://www.amazon.in/HEALLILY-Fretboard-Stick...
# 66  https://www.amazon.in/gp/slredirect/picassoRed...
#
# [67 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape
#
# following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone
#
# name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”,
#
# “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then
#
# replace it by “- “. Save your results in a dataframe and CSV.

# %%
#importing necessary libraries

import pandas as pd  #pandas are for making dataframes
import selenium      #for automating
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException #for exception handling

# %%
#automating the browser using webdriver

driver = webdriver.Chrome(r"C:\Users\91950\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.flipkart.com/search?q=pixel+4a&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=pixel+4a%7CMobiles&requestId=46524669-3e14-419d-9ff6-5cddf58bf033&as-backfill=on")

# %%
# We have to go to each page to extract the above information

urls1 = []
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls1.append(i.get_attribute("href"))

len(urls1)
# Out:
# 24

# %%
#applying loops
smartphone_name = [] 
price = [] 
ratings = [] 
description = [] 

for i in urls1:
    driver.get(i) 
    try:
        name = driver.find_element_by_xpath("//span[@class='B_NuCI']")
        smartphone_name.append(name.text)
    except:
        smartphone_name.append('-')         
    try:
        price1 =  driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        price.append(price1.text)
    except:
        price.append('-')   
    try:
        rate = driver.find_element_by_xpath("//span[@class='_2_R_DZ']")
        ratings.append(rate.text)
    except:
        ratings.append('-')
    try:
        desc= driver.find_element_by_xpath("//div[@class='_1mXcCf RmoJUa']")
        description.append(desc.text)
    except:
        description.append('-') 
    try:
        desc= driver.find_element_by_xpath("//div[@class='_1mXcCf RmoJUa']")
        description.append(desc.text)
    except:
        description.append('-') 
        
len(smartphone_name)
len(price)
len(ratings)
len(description)
# Out:
# 48

# %%
# making a dataframe

mobiles = pd.DataFrame({})

mobiles['Name of the smartphone']= smartphone_name
mobiles['Price']= price
mobiles['Ratings and reviews']= ratings
mobiles['url of the page']= urls1

mobiles  #displaying the dataset
# Out:
#                                Name of the smartphone    Price  \
# 0    Google Pixel 4a (Just Black, 128 GB)  (6 GB RAM)  ₹31,999
# 1        REDMI 9 Power (Fiery Red, 64 GB)  (4 GB RAM)  ₹11,499
# 2   REDMI 9 Power (Electric Green, 64 GB)  (4 GB RAM)  ₹11,499
# 3     REDMI 9 Power (Mighty Black, 64 GB)  (4 GB RAM)  ₹11,499
# 4           Redmi 9 (Carbon Black, 64 GB)  (4 GB RAM)   ₹9,348
# 5               Redmi 9 (Sky Blue, 64 GB)  (4 GB RAM)   ₹9,799
# 6                I Kall Z5 (Green, 16 GB)  (3 GB RAM)   ₹4,995
# 7            OPPO A16 (Pearl Blue, 64 GB)  (4 GB RAM)  ₹12,940
# 8         OPPO A16 (Crystal Black, 64 GB)  (4 GB RAM)  ₹12,547
# 9          Redmi 9 (Sporty Orange, 64 GB)  (4 GB RAM)   ₹9,295
# 10  Tecno Spark 7T (Nebula Orange, 128 GB)  (4 GB ...  ₹10,990
# 11  REDMI Note 10S (Cosmic Purple, 128 GB)  (6 GB ...  ₹17,249
# 12   REDMI 9 Power (Mighty Black, 128 GB)  (6 GB RAM)  ₹15,848
# 13      SAMSUNG Galaxy M02 (Black, 32 GB)  (2 GB RAM)   ₹8,253
# 14      Panasonic ELUGA I6 (Black, 16 GB)  (2 GB RAM)   ₹5,490
# 15              Redmi 9A (SeaBlue, 32 GB)  (2 GB RAM)   ₹7,698
# 16     SAMSUNG Galaxy A22 (Black, 128 GB)  (6 GB RAM)  ₹17,999
# 17    Tecno Spark 7 (Magnet Black, 32 GB)  (2 GB RAM)   ₹7,814
# 18  SAMSUNG Galaxy M31 (Space Black, 64 GB)  (6 GB...  ₹15,999
# 19  SAMSUNG Galaxy M52 5G (Icy Blue, 128 GB)  (6 G...  ₹26,382
# 20         Redmi 9A (Nature Green, 32 GB)  (2 GB RAM)   ₹7,699
# 21       Redmi 9A (Midnight Black, 32 GB)  (2 GB RAM)   ₹7,979
# 22    Tecno Spark 7 (Spruce Green, 32 GB)  (2 GB RAM)   ₹7,799
# 23  REDMI Note 10 Pro (Dark Night, 128 GB)  (6 GB ...  ₹19,988
#
#                   Ratings and reviews  \
# 0      36,583 Ratings & 5,645 Reviews
# 1   2,01,679 Ratings & 14,190 Reviews
# 2   2,01,679 Ratings & 14,190 Reviews
# 3   2,01,679 Ratings & 14,190 Reviews
# 4      21,833 Ratings & 1,260 Reviews
# 5      21,833 Ratings & 1,260 Reviews
# 6              73 Ratings & 4 Reviews
# 7              22 Ratings & 2 Reviews
# 8              22 Ratings & 2 Reviews
# 9      21,833 Ratings & 1,260 Reviews
# 10           173 Ratings & 15 Reviews
# 11        3,791 Ratings & 282 Reviews
# 12     41,457 Ratings & 3,194 Reviews
# 13           969 Ratings & 90 Reviews
# 14     10,373 Ratings & 1,049 Reviews
# 15       14,509 Ratings & 835 Reviews
# 16           471 Ratings & 37 Reviews
# 17           222 Ratings & 20 Reviews
# 18       10,514 Ratings & 779 Reviews
# 19                                  -
# 20       14,509 Ratings & 835 Reviews
# 21       14,509 Ratings & 835 Reviews
# 22           222 Ratings & 20 Reviews
# 23        2,585 Ratings & 210 Reviews
#
#                                       url of the page
# 0   https://www.flipkart.com/google-pixel-4a-just-...
# 1   https://www.flipkart.com/redmi-9-power-fiery-r...
# 2   https://www.flipkart.com/redmi-9-power-electri...
# 3   https://www.flipkart.com/redmi-9-power-mighty-...
# 4   https://www.flipkart.com/redmi-9-carbon-black-...
# 5   https://www.flipkart.com/redmi-9-sky-blue-64-g...
# 6   https://www.flipkart.com/kall-z5-green-16-gb/p...
# 7   https://www.flipkart.com/oppo-a16-pearl-blue-6...
# 8   https://www.flipkart.com/oppo-a16-crystal-blac...
# 9   https://www.flipkart.com/redmi-9-sporty-orange...
# 10  https://www.flipkart.com/tecno-spark-7t-nebula...
# 11  https://www.flipkart.com/redmi-note-10s-cosmic...
# 12  https://www.flipkart.com/redmi-9-power-mighty-...
# 13  https://www.flipkart.com/samsung-galaxy-m02-bl...
# 14  https://www.flipkart.com/panasonic-eluga-i6-bl...
# 15  https://www.flipkart.com/redmi-9a-seablue-32-g...
# 16  https://www.flipkart.com/samsung-galaxy-a22-bl...
# 17  https://www.flipkart.com/tecno-spark-7-magnet-...
# 18  https://www.flipkart.com/samsung-galaxy-m31-sp...
# 19  https://www.flipkart.com/samsung-galaxy-m52-5g...
# 20  https://www.flipkart.com/redmi-9a-nature-green...
# 21  https://www.flipkart.com/redmi-9a-midnight-bla...
# 22  https://www.flipkart.com/tecno-spark-7-spruce-...
# 23  https://www.flipkart.com/redmi-note-10-pro-dar...

# %%
driver.close()

# %% [markdown]
# Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
#importing necessary libraries

import pandas as pd  #pandas are for making dataframes
import selenium      #for automating
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException #for exception handling

# %%
#automating the browser using webdriver

driver = webdriver.Chrome(r"C:\Users\91950\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.google.com/")

# %%
#searching for barcelona on search page by using selenium

search = driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
search.send_keys("paris")

# %%
search_btn = driver.find_element_by_xpath("//input[@class='gNO89b']")
search_btn.click()

# %%
wiki_btn = driver.find_element_by_xpath("//h3[@class='LC20lb DKV0Md']")
wiki_btn.click()

# %%
co_ordinates = []

co_ord = driver.find_element_by_xpath("//span[@class='geo-dms']")
co_ordinates.append(co_ord.text)

# %%
co_ordinates
# Out:
# ['48°51′24″N 2°21′08″E']

# %%
driver.close()

# %% [markdown]
# Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”,
#
# “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
#automating the browser using webdriver

driver = webdriver.Chrome(r"C:\Users\91950\Downloads\chromedriver_win32\chromedriver.exe")
driver.get("https://www.forbes.com/?sh=235c0b332254")
